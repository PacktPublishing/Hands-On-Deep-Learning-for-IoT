# %% [markdown]
# # Chapter 9: DL for IoT Healthcare

# %% [markdown]
# # Use Case 2:  IoT for Acne detection and Care

# %% [markdown]
# # Model: MobileNet V1 (CNN)

# %% [markdown]
# # Step 1: Data Collection (downloading)

# %% [markdown]
# We do not have any dataset for this use case. We will scrap skin disease images from http://www.dermnet.com/

# %% [markdown]
# # Image Scraper

# %%
# Imports the modules
import requests
from bs4 import BeautifulSoup
import os
import shutil

# Root URL 

root_URL = 'http://www.dermnet.com/'

# Skin diseases types 
type_name = ['Acne-and-Rosacea-Photos', 'Actinic-Keratosis-Basal-Cell-Carcinoma-and-other-Malignant-Lesions', 
             'Atopic-Dermatitis-Photos', 'Bullous-Disease-Photos', 'Cellulitis-Impetigo-and-other-Bacterial-Infections', 
             'Eczema-Photos', 'Exanthems-and-Drug-Eruptions', 'Hair-Loss-Photos-Alopecia-and-other-Hair-Diseases',
             'Herpes-HPV-and-other-STDs-Photos', 'Light-Diseases-and-Disorders-of-Pigmentation',
             'Lupus-and-other-Connective-Tissue-diseases', 'Melanoma-Skin-Cancer-Nevi-and-Moles', 'Nail-Fungus-and-other-Nail-Disease', 
             'Poison-Ivy-Photos-and-other-Contact-Dermatitis', 'Psoriasis-pictures-Lichen-Planus-and-related-diseases', 
             'Scabies-Lyme-Disease-and-other-Infestations-and-Bites', 'Seborrheic-Keratoses-and-other-Benign-Tumors', 
             'Systemic-Disease', 'Tinea-Ringworm-Candidiasis-and-other-Fungal-Infections', 
             'Urticaria-Hives', 'Vascular-Tumors', 'Vasculitis-Photos', 'Warts-Molluscum-and-other-Viral-Infections']


type_LinksA = []
type_PagesA = []
type_SubLinksA = []

def find_max(link_):
    r_ = requests.get(link_)
    html_page1_1 = r_.text
    soup_page1_1 = BeautifulSoup(html_page1_1, "html5lib")

    navigationL = soup_page1_1.find_all("div", attrs={"class": "pagination"})
    max_ = 1
    last_ =1

    if not navigationL:
        pass
    else:
        for navi_ in navigationL: 
            for i in navi_.children:
                try:
                    i_ = i.contents[0]
                except:
                    pass
                else:
                    if i_ == 'Next':
                        max_ = int(last_)
                        break
                    else: 
                        last_ = i_
    return int(max_)

# Function to convert images to downloadble link for the images

def images2links(imagesL):
    thumbRLinks = []
    
    for url_ in imagesL:
        
        soup_page1_1_ = BeautifulSoup(requests.get(url_).text, "html5lib")

        for link in soup_page1_1_.find_all("img"):
            link_ = link.get("src")
            if 'Thumb' in link_:
                thumbRLinks.append(link_.replace('Thumb', ''))
    return list(set(thumbRLinks))

def download(url, image_path):
    try:
        r = requests.get(url, stream=True)
        if r.status_code == 200:
            with open(image_path, 'wb') as f:
                r.raw.decode_content = True
                shutil.copyfileobj(r.raw, f)
    except Exception as e:
        print (e)
        print ("Failed to save " + image_path)
        print (url + "\n")

    else:
        print ("Successfully saved " + image_path)

# %% [markdown]
# # Call the above functions and download the images

# %%
# Main function 
def main():
    for sub_ in type_name:
        SubLinks = []        
        r_ = requests.get(root_URL + '/images/' + sub_)
        html_page1 = r_.text
        soup_page1 = BeautifulSoup(html_page1, "html5lib")

        for link in soup_page1.find_all('a'):
            id_ = link.get('href')
            if '/images/' in id_:
                
                SubLinks.append(root_URL + id_)
        type_LinksA.append(SubLinks)

    attr = '/photos/'

    for type_ in type_LinksA:
        maxL_ = []
        thumbRLinks = []
        
        for link_ in type_:
            imagesL = []
            max_ = find_max(link_)
            maxL_.append(max_)
            print (link_)
            for i_ in range(max_):
                imagesL.append(link_ + attr + str(i_+1))
            
            print ("Pages: ", len(imagesL))
            realLinks = images2links(imagesL)
            print ("Links: ", len(realLinks))
            thumbRLinks.append(realLinks)

        type_PagesA.append(maxL_)
        type_SubLinksA.append(thumbRLinks)

    dir_root_stored_images = './DermnetDataset/'

    if os.path.exists(dir_root_stored_images):
        pass    
    else:
        os.mkdir(dir_root_stored_images) 
    for category in type_name:
        iloc = type_name.index(category)
        dir_disease = dir_root_stored_images + category + '/'
        
        if os.path.exists(dir_disease):
            pass    
        else:
            os.mkdir(dir_disease) 
            
        print ("Disease: ", dir_disease)
        for sub_ in type_LinksA[iloc]:
            iloc_sub = type_LinksA[iloc].index(sub_)
           
            dir_sub_disease = dir_disease + sub_.split('/')[-1]
            
            
            if os.path.exists(dir_sub_disease):
                pass    
            else:
                os.mkdir(dir_sub_disease)
            
            for l_ in type_SubLinksA[iloc][iloc_sub]:
                img_path = dir_sub_disease + '/' + l_.split('/')[-1]
                img_url = l_
                download(img_url, img_path)

if __name__ == "__main__":
    main()

# %% [raw]
# 23 Skin disease datasets will be downloaded and saved in the folder (DermnetDataset, in our case). Now select the first or Acne-and-Rosacea-Photos folder, and explore the subfolders, and prepare a reduced acne dataset as mentioned in the book.

# %% [markdown]
# # Step 2: Pre-processing

# %% [raw]
# The dataset we got are pre-processed as we can see from the data exploration above. Lets move to next step.

# %% [markdown]
# # Step 3: Model Training and Validation

# %%
Download the mobilenet_1.0_224 model from https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet_v1.
md, and save it into a dirctory that will be your model directory in the following code (we used Mobilenet)

# %%
import os
import argparse
import tensorflow as tf
from IPython.display import Image

import retrain  # Available in the usecase 2 folder

# %%
# Have a look at the default values
# For the meaning of these values look at retrain_CNN.py:

FLAGS = argparse.Namespace()
FLAGS.image_dir = ""
FLAGS.output_graph = '.\\retrained_graph.pb'
FLAGS.output_labels = '.\\output_labels.txt'
FLAGS.summaries_dir = '.\\summaries'
FLAGS.how_many_training_steps = 4000
FLAGS.learning_rate = 0.01
FLAGS.testing_percentage = 10
FLAGS.validation_percentage = 10
FLAGS.eval_step_interval = 10
FLAGS.train_batch_size = 100
FLAGS.test_batch_size = -1
FLAGS.validation_batch_size = 100
FLAGS.intermediate_store_frequency =10
FLAGS.print_misclassified_test_images = False
FLAGS.model_dir = "."
FLAGS.bottleneck_dir = "bottlenecks"
FLAGS.final_tensor_name = "final_result"
FLAGS.flip_left_right = False
FLAGS.random_crop = 0
FLAGS.random_scale = 0
FLAGS.random_brightness = 0
FLAGS.intermediate_output_graphs_dir ="."
FLAGS.architecture = "mobilenet_1.0_224"

# %%
# change default: 
FLAGS.how_many_training_steps = 500
FLAGS.model_dir = "Mobilenet"
# FLAGS.summaries_dir = "C:\\to\\temp" 
FLAGS.output_graph = "retrained_graph_v2.pb"  
FLAGS.output_labels = "retrained_labels.txt"
FLAGS.image_dir = "dataset-Acne-reduced"

# %%
retrain.FLAGS = FLAGS
tf.app.run(main=retrain.main)
# Out:
# INFO:tensorflow:Looking for images in 'Hidradenitis-Suppurativa'
# INFO:tensorflow:Looking for images in 'Rosacea'
# INFO:tensorflow:Looking for images in 'Perioral-Dermatitis'
# INFO:tensorflow:Looking for images in 'Acne-Cystic'
# INFO:tensorflow:100 bottleneck files created.
# INFO:tensorflow:200 bottleneck files created.
# INFO:tensorflow:300 bottleneck files created.
# INFO:tensorflow:400 bottleneck files created.
# INFO:tensorflow:500 bottleneck files created.
# INFO:tensorflow:2019-05-17 18:28:05.404075: Step 0: Train accuracy = 62.0%
# INFO:tensorflow:2019-05-17 18:28:05.405044: Step 0: Cross entropy = 1.240135
# INFO:tensorflow:2019-05-17 18:28:06.605404: Step 0: Validation accuracy = 52.0% (N=100)
# INFO:tensorflow:2019-05-17 18:28:07.176032: Step 10: Train accuracy = 64.0%
# INFO:tensorflow:2019-05-17 18:28:07.177150: Step 10: Cross entropy = 3.137362
# INFO:tensorflow:2019-05-17 18:28:07.248158: Step 10: Validation accuracy = 56.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_10.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:08.223718: Step 20: Train accuracy = 87.0%
# INFO:tensorflow:2019-05-17 18:28:08.224631: Step 20: Cross entropy = 0.440422
# INFO:tensorflow:2019-05-17 18:28:08.296018: Step 20: Validation accuracy = 82.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_20.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:09.198406: Step 30: Train accuracy = 75.0%
# INFO:tensorflow:2019-05-17 18:28:09.199671: Step 30: Cross entropy = 0.959767
# INFO:tensorflow:2019-05-17 18:28:09.268345: Step 30: Validation accuracy = 72.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_30.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:10.158262: Step 40: Train accuracy = 86.0%
# INFO:tensorflow:2019-05-17 18:28:10.159340: Step 40: Cross entropy = 0.370042
# INFO:tensorflow:2019-05-17 18:28:10.232751: Step 40: Validation accuracy = 82.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_40.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:11.188864: Step 50: Train accuracy = 92.0%
# INFO:tensorflow:2019-05-17 18:28:11.190295: Step 50: Cross entropy = 0.277757
# INFO:tensorflow:2019-05-17 18:28:11.265532: Step 50: Validation accuracy = 92.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_50.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:12.162318: Step 60: Train accuracy = 99.0%
# INFO:tensorflow:2019-05-17 18:28:12.163407: Step 60: Cross entropy = 0.039755
# INFO:tensorflow:2019-05-17 18:28:12.261097: Step 60: Validation accuracy = 91.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_60.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:13.261230: Step 70: Train accuracy = 80.0%
# INFO:tensorflow:2019-05-17 18:28:13.262453: Step 70: Cross entropy = 0.859860
# INFO:tensorflow:2019-05-17 18:28:13.338970: Step 70: Validation accuracy = 76.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_70.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:14.760166: Step 80: Train accuracy = 95.0%
# INFO:tensorflow:2019-05-17 18:28:14.761573: Step 80: Cross entropy = 0.123820
# INFO:tensorflow:2019-05-17 18:28:14.860441: Step 80: Validation accuracy = 93.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_80.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:16.117363: Step 90: Train accuracy = 73.0%
# INFO:tensorflow:2019-05-17 18:28:16.119495: Step 90: Cross entropy = 0.890875
# INFO:tensorflow:2019-05-17 18:28:16.214237: Step 90: Validation accuracy = 65.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_90.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:17.599375: Step 100: Train accuracy = 99.0%
# INFO:tensorflow:2019-05-17 18:28:17.601148: Step 100: Cross entropy = 0.082237
# INFO:tensorflow:2019-05-17 18:28:17.686685: Step 100: Validation accuracy = 91.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_100.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:19.031679: Step 110: Train accuracy = 97.0%
# INFO:tensorflow:2019-05-17 18:28:19.033030: Step 110: Cross entropy = 0.100689
# INFO:tensorflow:2019-05-17 18:28:19.132339: Step 110: Validation accuracy = 87.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_110.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:20.374614: Step 120: Train accuracy = 99.0%
# INFO:tensorflow:2019-05-17 18:28:20.375580: Step 120: Cross entropy = 0.070960
# INFO:tensorflow:2019-05-17 18:28:20.469900: Step 120: Validation accuracy = 89.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_120.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:21.538640: Step 130: Train accuracy = 99.0%
# INFO:tensorflow:2019-05-17 18:28:21.539880: Step 130: Cross entropy = 0.084142
# INFO:tensorflow:2019-05-17 18:28:21.661421: Step 130: Validation accuracy = 91.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_130.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:22.750511: Step 140: Train accuracy = 98.0%
# INFO:tensorflow:2019-05-17 18:28:22.751938: Step 140: Cross entropy = 0.072122
# INFO:tensorflow:2019-05-17 18:28:22.838968: Step 140: Validation accuracy = 93.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_140.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:23.995934: Step 150: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:23.997121: Step 150: Cross entropy = 0.044201
# INFO:tensorflow:2019-05-17 18:28:24.065606: Step 150: Validation accuracy = 88.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_150.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:25.159355: Step 160: Train accuracy = 99.0%
# INFO:tensorflow:2019-05-17 18:28:25.160639: Step 160: Cross entropy = 0.051481
# INFO:tensorflow:2019-05-17 18:28:25.249239: Step 160: Validation accuracy = 90.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_160.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:26.369277: Step 170: Train accuracy = 97.0%
# INFO:tensorflow:2019-05-17 18:28:26.370477: Step 170: Cross entropy = 0.060410
# INFO:tensorflow:2019-05-17 18:28:26.454691: Step 170: Validation accuracy = 88.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_170.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:27.722306: Step 180: Train accuracy = 99.0%
# INFO:tensorflow:2019-05-17 18:28:27.723618: Step 180: Cross entropy = 0.073453
# INFO:tensorflow:2019-05-17 18:28:27.801828: Step 180: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_180.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:28.870641: Step 190: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:28.871758: Step 190: Cross entropy = 0.029628
# INFO:tensorflow:2019-05-17 18:28:28.941416: Step 190: Validation accuracy = 96.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_190.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:30.334216: Step 200: Train accuracy = 98.0%
# INFO:tensorflow:2019-05-17 18:28:30.335376: Step 200: Cross entropy = 0.067607
# INFO:tensorflow:2019-05-17 18:28:30.545842: Step 200: Validation accuracy = 89.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_200.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:31.738629: Step 210: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:31.740039: Step 210: Cross entropy = 0.026206
# INFO:tensorflow:2019-05-17 18:28:31.804317: Step 210: Validation accuracy = 90.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_210.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:32.763361: Step 220: Train accuracy = 99.0%
# INFO:tensorflow:2019-05-17 18:28:32.764587: Step 220: Cross entropy = 0.050171
# INFO:tensorflow:2019-05-17 18:28:32.831883: Step 220: Validation accuracy = 84.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_220.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:33.761528: Step 230: Train accuracy = 99.0%
# INFO:tensorflow:2019-05-17 18:28:33.762712: Step 230: Cross entropy = 0.041310
# INFO:tensorflow:2019-05-17 18:28:33.827743: Step 230: Validation accuracy = 89.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_230.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:34.898334: Step 240: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:34.899810: Step 240: Cross entropy = 0.029800
# INFO:tensorflow:2019-05-17 18:28:34.973788: Step 240: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_240.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:36.273569: Step 250: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:36.274783: Step 250: Cross entropy = 0.041859
# INFO:tensorflow:2019-05-17 18:28:36.351023: Step 250: Validation accuracy = 95.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_250.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:37.350692: Step 260: Train accuracy = 99.0%
# INFO:tensorflow:2019-05-17 18:28:37.352048: Step 260: Cross entropy = 0.052213
# INFO:tensorflow:2019-05-17 18:28:37.440757: Step 260: Validation accuracy = 89.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_260.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:38.419733: Step 270: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:38.421023: Step 270: Cross entropy = 0.024480
# INFO:tensorflow:2019-05-17 18:28:38.495985: Step 270: Validation accuracy = 94.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_270.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:39.498611: Step 280: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:39.499706: Step 280: Cross entropy = 0.026963
# INFO:tensorflow:2019-05-17 18:28:39.568488: Step 280: Validation accuracy = 89.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_280.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:40.871499: Step 290: Train accuracy = 88.0%
# INFO:tensorflow:2019-05-17 18:28:40.872821: Step 290: Cross entropy = 0.182819
# INFO:tensorflow:2019-05-17 18:28:40.955255: Step 290: Validation accuracy = 82.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_290.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:42.190372: Step 300: Train accuracy = 96.0%
# INFO:tensorflow:2019-05-17 18:28:42.191616: Step 300: Cross entropy = 0.089862
# INFO:tensorflow:2019-05-17 18:28:42.274849: Step 300: Validation accuracy = 89.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_300.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:43.375231: Step 310: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:43.376342: Step 310: Cross entropy = 0.038010
# INFO:tensorflow:2019-05-17 18:28:43.456154: Step 310: Validation accuracy = 89.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_310.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:44.580054: Step 320: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:44.581141: Step 320: Cross entropy = 0.035960
# INFO:tensorflow:2019-05-17 18:28:44.662420: Step 320: Validation accuracy = 93.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_320.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:45.983922: Step 330: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:45.985179: Step 330: Cross entropy = 0.031208
# INFO:tensorflow:2019-05-17 18:28:46.099544: Step 330: Validation accuracy = 89.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_330.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:47.483750: Step 340: Train accuracy = 99.0%
# INFO:tensorflow:2019-05-17 18:28:47.485360: Step 340: Cross entropy = 0.046685
# INFO:tensorflow:2019-05-17 18:28:47.558610: Step 340: Validation accuracy = 87.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_340.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:48.570912: Step 350: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:48.572025: Step 350: Cross entropy = 0.017455
# INFO:tensorflow:2019-05-17 18:28:48.643002: Step 350: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_350.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:49.651958: Step 360: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:49.653350: Step 360: Cross entropy = 0.016516
# INFO:tensorflow:2019-05-17 18:28:49.709421: Step 360: Validation accuracy = 94.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_360.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:50.819136: Step 370: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:50.820632: Step 370: Cross entropy = 0.020012
# INFO:tensorflow:2019-05-17 18:28:50.891669: Step 370: Validation accuracy = 94.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_370.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:52.095890: Step 380: Train accuracy = 99.0%
# INFO:tensorflow:2019-05-17 18:28:52.098307: Step 380: Cross entropy = 0.030090
# INFO:tensorflow:2019-05-17 18:28:52.190608: Step 380: Validation accuracy = 91.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_380.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:53.154242: Step 390: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:53.155633: Step 390: Cross entropy = 0.021969
# INFO:tensorflow:2019-05-17 18:28:53.211859: Step 390: Validation accuracy = 86.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_390.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:54.093026: Step 400: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:54.094139: Step 400: Cross entropy = 0.018230
# INFO:tensorflow:2019-05-17 18:28:54.148880: Step 400: Validation accuracy = 89.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_400.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:55.046226: Step 410: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:55.047365: Step 410: Cross entropy = 0.017684
# INFO:tensorflow:2019-05-17 18:28:55.102854: Step 410: Validation accuracy = 95.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_410.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:55.992305: Step 420: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:55.993422: Step 420: Cross entropy = 0.017807
# INFO:tensorflow:2019-05-17 18:28:56.051786: Step 420: Validation accuracy = 94.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_420.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:57.180477: Step 430: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:57.182657: Step 430: Cross entropy = 0.012581
# INFO:tensorflow:2019-05-17 18:28:57.251551: Step 430: Validation accuracy = 93.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_430.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:28:58.874209: Step 440: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:28:58.875577: Step 440: Cross entropy = 0.022876
# INFO:tensorflow:2019-05-17 18:28:58.950756: Step 440: Validation accuracy = 96.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_440.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:29:00.412405: Step 450: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:29:00.415022: Step 450: Cross entropy = 0.016415
# INFO:tensorflow:2019-05-17 18:29:00.491864: Step 450: Validation accuracy = 95.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_450.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:29:01.666440: Step 460: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:29:01.667671: Step 460: Cross entropy = 0.017588
# INFO:tensorflow:2019-05-17 18:29:01.755655: Step 460: Validation accuracy = 92.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_460.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:29:03.039888: Step 470: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:29:03.041316: Step 470: Cross entropy = 0.017830
# INFO:tensorflow:2019-05-17 18:29:03.121075: Step 470: Validation accuracy = 87.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_470.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:29:04.350493: Step 480: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:29:04.352412: Step 480: Cross entropy = 0.023055
# INFO:tensorflow:2019-05-17 18:29:04.418346: Step 480: Validation accuracy = 90.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_480.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:29:05.518806: Step 490: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:29:05.520263: Step 490: Cross entropy = 0.013724
# INFO:tensorflow:2019-05-17 18:29:05.629703: Step 490: Validation accuracy = 92.0% (N=100)
# INFO:tensorflow:Save intermediate result to : .intermediate_490.pb
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# INFO:tensorflow:2019-05-17 18:29:06.575952: Step 499: Train accuracy = 100.0%
# INFO:tensorflow:2019-05-17 18:29:06.577172: Step 499: Cross entropy = 0.018546
# INFO:tensorflow:2019-05-17 18:29:06.634827: Step 499: Validation accuracy = 91.0% (N=100)
# INFO:tensorflow:Final test accuracy = 86.3% (N=51)
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %% [markdown]
# # Step 4: Test model on new picture individual Acne Images in Raspberry Pi or Other Devices.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function


import numpy as np
import tensorflow as tf
# Function to load a pretrained model (transfer learning)

def load_graph(model_file):
  graph = tf.Graph()
  graph_def = tf.GraphDef()

  with open(model_file, "rb") as f:
    graph_def.ParseFromString(f.read())
  with graph.as_default():
    tf.import_graph_def(graph_def)

  return graph

# Function for image to tensor conversion

def read_tensor_from_image_file(file_name,
                                input_height=299,
                                input_width=299,
                                input_mean=0,
                                input_std=255):
  input_name = "file_reader"
  #output_name = "normalized"
  file_reader = tf.read_file(file_name, input_name)
  if file_name.endswith(".png"):
    image_reader = tf.image.decode_png(
        file_reader, channels=3, name="png_reader")
  elif file_name.endswith(".gif"):
    image_reader = tf.squeeze(
        tf.image.decode_gif(file_reader, name="gif_reader"))
  elif file_name.endswith(".bmp"):
    image_reader = tf.image.decode_bmp(file_reader, name="bmp_reader")
  else:
    image_reader = tf.image.decode_jpeg(
        file_reader, channels=3, name="jpeg_reader")
  float_caster = tf.cast(image_reader, tf.float32)
  dims_expander = tf.expand_dims(float_caster, 0)
  resized = tf.image.resize_bilinear(dims_expander, [input_height, input_width])
  normalized = tf.divide(tf.subtract(resized, [input_mean]), [input_std])
  sess = tf.Session()
  result = sess.run(normalized)

  return result

# Function for loading label files

def load_labels(label_file):
  label = []
  proto_as_ascii_lines = tf.gfile.GFile(label_file).readlines()
  for l in proto_as_ascii_lines:
    label.append(l.rstrip())
  return label

# %%
# Provide input to be predicted with model file and label or class file 
file_name = "test_images/Acne_test1.jpg"
model_file = "retrained_graph_v2.pb"
label_file = "retrained_labels.txt"

# Fixed input for Mobilenet V1
input_height = 224
input_width = 224
input_mean = 0
input_std = 255
input_layer = "input"
output_layer = "final_result"

# Load the model
graph = load_graph(model_file)
t = read_tensor_from_image_file(
      file_name,
      input_height=input_height,
      input_width=input_width,
      input_mean=input_mean,
      input_std=input_std)

input_name = "import/" + input_layer
output_name = "import/" + output_layer
input_operation = graph.get_operation_by_name(input_name)
output_operation = graph.get_operation_by_name(output_name)

with tf.Session(graph=graph) as sess:
    results = sess.run(output_operation.outputs[0], {
        input_operation.outputs[0]: t
    })

results = np.squeeze(results)

top_k = results.argsort()[-5:][::-1]
labels = load_labels(label_file)
for i in top_k:
    print("Pontenially", labels[i], "with confidence level",results[i])
# Out:
# Pontenially acne cystic with confidence 0.9969146
# Pontenially hidradenitis suppurativa with confidence 0.0019573767
# Pontenially rosacea with confidence 0.0011249987
# Pontenially perioral dermatitis with confidence 2.9915207e-06
